# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import galsim

# %%
dir = './temp/g1_0_val_0.020/img_0/'
df = pd.read_csv(dir + 'full_image.csv')
full_image = np.load(dir + 'full_image.npy')
cutout = np.load(dir + 'cutouts.npy')

dir = './temp/g1_2_val_0.020/img_0/'
df = pd.read_csv(dir + 'full_image.csv')
full_image = np.load(dir + 'full_image.npy')
cutout_1 = np.load(dir + 'cutouts.npy')

# %%
plt.imshow(cutout[15]-cutout_1[15], origin='lower', cmap='grey')
plt.colorbar()
plt.show()

plt.imshow(cutout[15], origin='lower', cmap='grey')
plt.colorbar()
plt.show()
